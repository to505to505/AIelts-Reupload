# %%
import sys
import os
from dotenv import load_dotenv
load_dotenv()
sys.path.append(os.getenv("PYTHONPATH"))

from src.services.transcriber import transcribe_audio

# %%
result = await transcribe_audio('sj0nb305blrt97u', 'br8tdd767kvy83f')
# Out:
# LOADING AUDIO FILE...:  https://pb.aielts.ru/api/files/pbc_3246635500/sj0nb305blrt97u/audio_i1quaqvzw1.mp3
# DETECTED EXTENSION: .mp3
# Converting audio file to wav format...
# Conversion complete. Sending wav file to OPENAI...
# ...
